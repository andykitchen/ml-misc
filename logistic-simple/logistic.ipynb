# %%
import logistic
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
reload(logistic)
#loss, test_accuracy = logistic.run(epochs=20, learning_rate=1, regularization=.01, norm_limit=1.2)
loss, test_accuracy = logistic.run(epochs=20, learning_rate=1, regularization=.01, norm_limit=1.2)
fig = plt.figure(figsize=(16,4))
ax1 = plt.subplot(131)
ax1.plot(loss)
ax2 = plt.subplot(132)
ax2.plot(test_accuracy)
ax3 = plt.subplot(133)
ax3.plot(logistic.model.beta, '.')
print test_accuracy[-1]
print np.linalg.norm(logistic.model.beta)
# Out:
# 0.98
# 1.16580583876
